# %%
from probabilistic_classifier.experiment import multiclass_probabilistic_classifier_experiment, midiff_experiment

# %%
prime = None
data_range = None
num_of_samples = 5000

hidden_size_arr = [256, 256]
lr = 0.001

num_of_outer_iteration = 20
num_of_inner_iteration = 50
batch_size = 4096

para_param, priv_param = None, None
beta_arr, alpha_arr = None, None

feature_size = None
weight = None
z_dim = 100
x_idx, y_idx, z_idx = [0], [1], list(range(2, z_dim + 2))

# %%
curr_ldr = multiclass_probabilistic_classifier_experiment(prime, data_range, num_of_samples, weight, feature_size, beta_arr, alpha_arr, para_param, priv_param, x_idx, y_idx, z_idx, hidden_size_arr, lr, num_of_outer_iteration, num_of_inner_iteration, batch_size, load_data='./data/catNon-lin-NI_13/data.5k.dz100.seed0.npy')
# Out:
# ################################################################
# trial: 1, epoch, 1, iter: 1, curr loss: 1.4114891290664673, avg loss: 1.4114891290664673
# trial: 1, epoch, 2, iter: 1, curr loss: 1.3883874416351318, avg loss: 1.3883874416351318
# trial: 1, epoch, 3, iter: 1, curr loss: 1.3872789144515991, avg loss: 1.3872789144515991
# trial: 1, epoch, 4, iter: 1, curr loss: 1.3869102001190186, avg loss: 1.3869102001190186
# trial: 1, epoch, 5, iter: 1, curr loss: 1.3868993520736694, avg loss: 1.3868993520736694
# trial: 1, epoch, 6, iter: 1, curr loss: 1.3869130611419678, avg loss: 1.3869130611419678
# trial: 1, epoch, 7, iter: 1, curr loss: 1.3865668773651123, avg loss: 1.3865668773651123
# trial: 1, epoch, 8, iter: 1, curr loss: 1.386558175086975, avg loss: 1.386558175086975
# trial: 1, epoch, 9, iter: 1, curr loss: 1.3862698078155518, avg loss: 1.3862698078155518
# trial: 1, epoch, 10, iter: 1, curr loss: 1.3864046335220337, avg loss: 1.3864046335220337
# ...

# %%
midiff_experiment(prime, data_range, num_of_samples, weight, feature_size, beta_arr, alpha_arr, para_param,
                      priv_param, x_idx, y_idx, z_idx, hidden_size_arr, lr, num_of_outer_iteration,
                      num_of_inner_iteration, batch_size, load_data='./data/catNon-lin-NI_13/data.5k.dz100.seed0.npy')
# Out:
# ################################################################
# trial: 1, epoch, 1, iter: 1, curr loss: 0.6992483139038086, avg loss: 0.6992483139038086
# trial: 1, epoch, 2, iter: 1, curr loss: 0.6945605278015137, avg loss: 0.6945605278015137
# trial: 1, epoch, 3, iter: 1, curr loss: 0.6943486332893372, avg loss: 0.6943486332893372
# trial: 1, epoch, 4, iter: 1, curr loss: 0.6934179067611694, avg loss: 0.6934179067611694
# trial: 1, epoch, 5, iter: 1, curr loss: 0.6939009428024292, avg loss: 0.6939009428024292
# trial: 1, epoch, 6, iter: 1, curr loss: 0.6945809125900269, avg loss: 0.6945809125900269
# trial: 1, epoch, 7, iter: 1, curr loss: 0.6933860778808594, avg loss: 0.6933860778808594
# trial: 1, epoch, 8, iter: 1, curr loss: 0.6930966973304749, avg loss: 0.6930966973304749
# trial: 1, epoch, 9, iter: 1, curr loss: 0.6933490633964539, avg loss: 0.6933490633964539
# trial: 1, epoch, 10, iter: 1, curr loss: 0.6932677030563354, avg loss: 0.6932677030563354
# ...
